# %%
import gstools as gs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_12445/1990075729.py in <module>
# ----> 1 import gstools as gs
#
# ModuleNotFoundError: No module named 'gstools'
