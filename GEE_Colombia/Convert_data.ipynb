# %%
import georasters as gr
import geopandas as gpd

# %%
NO2=gr.from_file('methane.tif')
NO2df=NO2.to_geopandas()

# %%
NO2df[NO2df['value']!=0].plot(column='value',legend=True)
# Out:
# <AxesSubplot: >

# %%
NO2df[NO2df['value']!=0]
# Out:
#        row  col        value          x          y  \
# 126      0  126  1884.592122 -73.572022  15.091697
# 127      0  127  1890.323550 -73.482190  15.091697
# 128      0  128  1904.316683 -73.392359  15.091697
# 129      0  129  1906.749793 -73.302527  15.091697
# 130      0  130  1900.959054 -73.212696  15.091697
# ...    ...  ...          ...        ...        ...
# 42779  212  167  1844.674832 -69.888929  -3.952587
# 42976  213  163  1840.778707 -70.248255  -4.042419
# 42977  213  164  1842.373164 -70.158424  -4.042419
# 42979  213  166  1834.933840 -69.978761  -4.042419
# 43179  214  165  1850.595729 -70.068592  -4.132250
#
#                                                 geometry
# 126    POLYGON ((-73.57202 15.09170, -73.48219 15.091...
# 127    POLYGON ((-73.48219 15.09170, -73.39236 15.091...
# 128    POLYGON ((-73.39236 15.09170, -73.30253 15.091...
# 129    POLYGON ((-73.30253 15.09170, -73.21270 15.091...
# 130    POLYGON ((-73.21270 15.09170, -73.12286 15.091...
# ...

# %%
CH4=gr.from_file('methane5000.tif')

# %%
CH4df=CH4.to_geopandas()

# %%
CH4df[CH4df['value']!=0].plot(column='value',legend=True)
# Out:
# <AxesSubplot: >

# %%
#CH4df.to_csv('ch4_092022_122022.csv')

# %%
CH4df.shape[0]
# Out:
# 172430

# %%
NO2df.shape[0]
# Out:
# 58745097

# %%
CH4gdf=CH4.to_geopandas()

# %%
NO2gdf.head(20)
