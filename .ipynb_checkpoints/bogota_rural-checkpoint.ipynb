# %% [markdown]
# ## Inicializar los paquetes de Google Earth Engine (GEE)
#
# Iniciando sesión con la cuenta previamente creada y obteniendo el código de permiso para el uso del API

# %%
import ee
import geemap
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=o3_7duBPZaJ1Duke7A5A-zVp5gEKX7SQQF_jWCJhyLk&tc=eu0i6-PAs_O35wTkKNNfMN163ZNyNUudojSLngTqiwQ&cc=rbiAI8tTrFvjm140iZZgCrUrMMSgJlbymIqdlpy9GI0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=o3_7duBPZaJ1Duke7A5A-zVp5gEKX7SQQF_jWCJhyLk&tc=eu0i6-PAs_O35wTkKNNfMN163ZNyNUudojSLngTqiwQ&cc=rbiAI8tTrFvjm140iZZgCrUrMMSgJlbymIqdlpy9GI0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AWtgzh7jEPAQNfwhiu1hvtPNJqDA1YMvK-VZm9QibDyv4hwQVEw0k07vn8M
# Successfully saved authorization token.

# %% [markdown]
# ## Conseguir los archivos .shp del mapa de Bogotá
#
# Estos archivos fueron cargados previamente en la nube de GEE para su posterior tratamiento

# %%
bogota_localidades = ee.FeatureCollection('projects/ee-seforeros/assets/2022_localidades')

map = geemap.map()
map = geemap.Map(bogota_localidades,{},'cualquiera',1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7688\1695167213.py in <module>
#       1 bogota_localidades = ee.FeatureCollection('projects/ee-seforeros/assets/2022_localidades')
#       2
# ----> 3 map = geemap.Map(bogota_localidades,{},'cualquiera',1)
#
# TypeError: __init__() takes 1 positional argument but 5 were given
